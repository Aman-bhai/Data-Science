# %%
a,b,x,y=7,8,9,22

# %%
def Maximum(a, b):
    if a>=b:
        return a
    else:
        return b

c = Maximum(a,b)
print(c)
# Out:
# 8

# %%
def fact(n):
  facto=n
  if facto==0 :
    return 1
  facto=facto*fact(n-1)
  return facto

a=fact(b)
a
# Out:
# 40320

# %%
def sum(x,y,z):
  return x+y+z

x=int(input())
y=int(input())
z=int(input())

print("sum of x,y,z: ",sum(x,y,z))
# Out:
# 4
# 5
# 6
# sum of x,y,z:  15

# %%
def name(*x):     # asterisk is used when length/values/arguement of the function is not known
  for i in x:
    print(i)
name('aman','bhai','mike','morena','goa','gandinagar')
# Out:
# aman
# bhai
# mike
# morena
# goa
# gandinagar

# %%
def fib(n):
  a,b,c=0,1,0
  for x in range(0,n+1):
    print(c,end=" ")
    a=b
    b=c
    c=a+b

i=int(input("enter the no. upto which fibonicci series obtained:"))
fib(i)
# Out:
# enter the no. upto which fibonicci series obtained:5
# 0 1 1 2 3 5

# %% [markdown]
# ***lambda function***

# %%
sum=lambda x,y:x+y
print(sum(4,5))
# Out:
# 9

# %%
l=[3,4,6,7,8,8]
print(list(filter ((lambda i:i%2==0),l)))     # filter lambda
# Out:
# [4, 6, 8, 8]

# %%
a=lambda i,j=0,k=1:i+j+k
print(a(2,4))
# Out:
# 7

# %%
print(list(map(lambda x:x**2,l)))
# Out:
# [9, 16, 36, 49, 64, 64]
